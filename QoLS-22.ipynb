# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/raw_survey_data_2022.csv',header=None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1594 entries, 0 to 1593
# Columns: 351 entries, 0 to 350
# dtypes: object(351)
# memory usage: 4.3+ MB

# %%
data
# Out:
#         0              1              2    \
# 0     Index     Start Date       End Date
# 1       NaN            NaN            NaN
# 2         0    4/6/22 7:37    4/7/22 2:57
# 3         1    4/6/22 0:03    4/7/22 0:13
# 4         2   4/6/22 23:42    4/7/22 0:03
# ...     ...            ...            ...
# 1589   1587  3/23/22 12:01  3/23/22 12:15
# 1590   1588  3/23/22 12:01  3/23/22 12:13
# 1591   1589  3/23/22 12:01  3/23/22 12:12
# 1592   1590  3/23/22 12:01  3/23/22 12:11
# 1593   1591  3/23/22 12:04  3/23/22 12:05
#
#                                                          3    \
# 0     I am satisfied with my overall experience at Columbia.
# 1                                                   Response
# 2                                                      Agree
# 3                                                      Agree
# 4                                                   Disagree
# ...                                                      ...
# 1589                                                   Agree
# 1590                                          Strongly agree
# 1591                                                   Agree
# 1592                                       Strongly disagree
# 1593                               Neither agree or disagree
#
#                                                                                        4    \
# 0     I am satisfied with the following with respect to my overall experience at Columbia.
# 1                                                                                Academics
# 2                                                                           Strongly agree
# 3                                                                                    Agree
# 4                                                                                 Disagree
# ...                                                                                    ...
# 1589                                                            Neither agree nor disagree
# 1590                                                                        Strongly agree
# 1591                                                                                 Agree
# 1592                                                                     Strongly disagree
# 1593                                                            Neither agree nor disagree
#
#                     5                           6    \
# 0                   NaN                         NaN
# 1         Mental health             Physical health
# 2                 Agree                       Agree
# 3                 Agree                       Agree
# 4              Disagree                       Agree
# ...                 ...                         ...
# 1589              Agree              Strongly agree
# 1590     Strongly agree              Strongly agree
# 1591              Agree                       Agree
# 1592  Strongly disagree           Strongly disagree
# 1593           Disagree  Neither agree nor disagree
#
#                              7                           8    \
# 0                            NaN                         NaN
# 1       Professional development                 Social life
# 2                          Agree                       Agree
# 3                          Agree                       Agree
# 4                          Agree                       Agree
# ...                          ...                         ...
# 1589              Strongly agree              Strongly agree
# 1590              Strongly agree                       Agree
# 1591                       Agree                       Agree
# 1592           Strongly disagree           Strongly disagree
# 1593  Neither agree nor disagree  Neither agree nor disagree
#
#                              9    ...                      341  \
# 0                            NaN  ...                      NaN
# 1          Career Placement Team  ...  Prefer to self-describe
# 2                          Agree  ...                      NaN
# 3                          Agree  ...                      NaN
# 4     Neither agree nor disagree  ...                      NaN
# ...                          ...  ...                      ...
# 1589  Neither agree nor disagree  ...                      NaN
# 1590                       Agree  ...                      NaN
# 1591                       Agree  ...                      NaN
# 1592           Strongly disagree  ...                      NaN
# 1593  Neither agree nor disagree  ...                      NaN
#
#                                                            342  \
# 0     Do you identify yourself as part of the LGBTQ community?
# 1                                                     Response
# 2                                                           No
# 3                                                          NaN
# 4                                                           No
# ...                                                        ...
# 1589                                                        No
# 1590                                                        No
# 1591                                                       NaN
# 1592                                    I prefer not to answer
# 1593                                                       NaN
#
#                                           343                     344  \
# 0     Please identify your ethnic background.                     NaN
# 1                                    Response  Other (please specify)
# 2                      Multiracial background                     NaN
# 3                                         NaN                     NaN
# 4                                 South Asian                     NaN
# ...                                       ...                     ...
# 1589                              South Asian                     NaN
# 1590                              South Asian                     NaN
# 1591                                      NaN                     NaN
# 1592                              South Asian                     NaN
# 1593                                      NaN                     NaN
#
#                      345                     346                        347  \
# 0      Country of Origin                     NaN  What is your current age?
# 1               Response  Other (please specify)                   Response
# 2           Jamaica (NA)                     NaN               less than 18
# 3                    NaN                     NaN                        NaN
# 4             India (AS)                     NaN                      21-23
# ...                  ...                     ...                        ...
# 1589  United States (NA)                     NaN                      24-26
# 1590          India (AS)                     NaN                      27-29
# 1591                 NaN                     NaN                        NaN
# 1592          India (AS)                     NaN                      24-26
# 1593                 NaN                     NaN                        NaN
#
#                                   348  \
# 0     Is English your first language?
# 1                            Response
# 2                                 Yes
# 3                                 NaN
# 4                                 Yes
# ...                               ...
# 1589                              Yes
# 1590                               No
# 1591                              NaN
# 1592                              Yes
# 1593                              NaN
#
#                                                                              349  \
# 0     Was English the medium of instruction in your primary or secondary school?
# 1                                                                       Response
# 2                                                                            Yes
# 3                                                                            NaN
# 4                                                                            Yes
# ...                                                                          ...
# 1589                                                                         Yes
# 1590                                                                         Yes
# 1591                                                                         NaN
# 1592                                                                         Yes
# 1593                                                                         NaN
#
#                                                                                 350
# 0     Let us know about other important matters that are not covered by this survey
# 1                                                               Open-Ended Response
# 2                                                                               NaN
# 3                                                                               NaN
# 4                                                                               NaN
# ...                                                                             ...
# 1589                                                                            NaN
# 1590                                                                            NaN
# 1591                                                                            NaN
# 1592                                                                            NaN
# 1593                                                                            NaN
#
# [1594 rows x 351 columns]

# %% [markdown]
# ## Creating Question Table

# %%
# create the table of the first 2 rows to see the questions and the columns they locate
Q=data.iloc[:2,:].T
Q.columns=['Question','Sub_Question']
#Q['location']=[ lambda x: x.index*(x.Question.isna()==False)]
Q['location']=np.where(Q.Question.isna()==False, Q.Question.index, "False")

# %%
pd.options.display.max_colwidth=120

# %%
Q[Q.location!="False"]
# Out:
#                                                                                  Question  \
# 0                                                                                   Index
# 1                                                                              Start Date
# 2                                                                                End Date
# 3                                  I am satisfied with my overall experience at Columbia.
# 4    I am satisfied with the following with respect to my overall experience at Columbia.
# ..                                                                                    ...
# 345                                                                     Country of Origin
# 347                                                             What is your current age?
# 348                                                       Is English your first language?
# 349            Was English the medium of instruction in your primary or secondary school?
# 350         Let us know about other important matters that are not covered by this survey
#
#             Sub_Question location
# 0                    NaN        0
# 1                    NaN        1
# 2                    NaN        2
# 3               Response        3
# 4              Academics        4
# ..                   ...      ...
# 345             Response      345
# 347             Response      347
# 348             Response      348
# 349             Response      349
# 350  Open-Ended Response      350
#
# [112 rows x 3 columns]

# %%
Q.to_csv("output/Questions-22.csv", index=True)
